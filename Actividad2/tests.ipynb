# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso

# %%
x = np.arange(0, 30)
y = [3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 62, 70, 75, 88, 81, 87, 95, 100, 108, 135, 151, 160, 169, 179]
y = (np.array(y)/10)**0.25 - x/16
plt.figure(figsize=(5,3))
plt.scatter(x, y, marker='.')
plt.show()

# %%
linear = LinearRegression().fit(x.reshape(-1, 1), y)

poly_features = PolynomialFeatures(degree=6, include_bias=False).fit_transform(x.reshape(-1, 1))
polinomial = LinearRegression().fit(poly_features, y)

ridge_regr = Ridge(alpha=0.8, max_iter=2500000).fit(poly_features, y)

lasso_regr = Lasso(alpha=5e-5, max_iter=2500000).fit(poly_features, y)
# Out:
# d:\VSCode\UC\Curso 3 Aplicaciones IA\entornoConda\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.0009e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# d:\VSCode\UC\Curso 3 Aplicaciones IA\entornoConda\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.928e-02, tolerance: 8.455e-05
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.figure(figsize=(10,6))
plt.scatter(x, y, marker='.')
plt.plot(x, linear.predict(x.reshape(-1, 1)), c='#ff0000')
plt.plot(x, polinomial.predict(poly_features), c='#00dd00')
plt.plot(x, ridge_regr.predict(poly_features), c='#bb00bb')
plt.plot(x, lasso_regr.predict(poly_features), c='#ddbb00')
plt.show()
